# %% [markdown]
# <h2>Tugas Harian 2</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note : warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

fig, ax = plt.subplots(figsize=[15,8])
ax.plot(cos, linestyle='-', color='red', label='Cosx')
ax.plot(cos3, linestyle='--', color='green', label='3Cosx')
ax.plot(sin, linestyle='dashdot', color='blue', label='Sin(x-90)')
ax.plot(sin2, linestyle=' ', marker='x', color='yellow', label='2 Sinx')
plt.legend(loc='center')

ax.set_xlabel('X Label Axis')
ax.set_ylabel('Y Label Axis')
ax.set_title('Grafik Cos-Sin')

plt.show()

# %% [markdown]
# Expected Result :
#
# ![image.png](attachment:image.png)
